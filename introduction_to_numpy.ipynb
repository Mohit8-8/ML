# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit8-8/ML/blob/main/introduction_to_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# ### **DATATYPES AND ATTRIBUTES**

# %%
#numpy's main datatype is ndarray (ndarray - n dimensional array)
a1=np.array([1,2,3])
a1
# Out:
# array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[1.0,2.0,3.0],[4,5,6]])
a2
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
a1.shape
# Out:
# (3,)

# %%
a2.shape
# Out:
# (2, 3)

# %%
a1.ndim,a2.ndim
# Out:
# (1, 2)

# %%
a1.dtype , a2.dtype
# Out:
# (dtype('int64'), dtype('float64'))

# %%
a1.size, a2.size
# Out:
# (3, 6)

# %%
#create a dataframe from a numpy array

import pandas as pd

df = pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0

# %% [markdown]
# ### **CREATING ARRAYS**

# %%
sample_array = np.array([1,2,3,4])
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
sample_array.dtype
# Out:
# dtype('int64')

# %%
ones = np.ones((2,3))
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
zeros=np.zeros((2,3))
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0,10,2) #like a python range function
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0,10,size=(3,5))
random_array
# Out:
# array([[9, 4, 1, 4, 5],
#        [6, 1, 0, 2, 4],
#        [0, 1, 1, 1, 5]])

# %%
ra = np.random.random((5,3)) #gives random values between 0 and 1
ra
# Out:
# array([[0.11264079, 0.39280749, 0.2582399 ],
#        [0.26453415, 0.26590124, 0.56186233],
#        [0.57212693, 0.14837446, 0.90510414],
#        [0.29723048, 0.70684256, 0.33961456],
#        [0.08943329, 0.43196797, 0.11965391]])

# %%
#pesudo-random numbers
#np.random.seed()
ra2 = np.random.randint(10,size=(5,3))
ra2
# Out:
# array([[8, 1, 8],
#        [8, 5, 7],
#        [3, 9, 8],
#        [4, 3, 5],
#        [7, 0, 7]])

# %%
np.random.seed(7) # it keeps the random number the same (when we share files with someone this helps keep it the same)
ra3 = np.random.random((5,3))
ra3
# Out:
# array([[0.07630829, 0.77991879, 0.43840923],
#        [0.72346518, 0.97798951, 0.53849587],
#        [0.50112046, 0.07205113, 0.26843898],
#        [0.4998825 , 0.67923   , 0.80373904],
#        [0.38094113, 0.06593635, 0.2881456 ]])

# %%
ra4=np.random.randint(10,size=(3,3))
ra4
# Out:
# array([[3, 5, 8],
#        [8, 7, 5],
#        [0, 0, 2]])

# %%
np.unique(ra4) #gives only the unique elements no doubles
# Out:
# array([0, 2, 3, 5, 7, 8])

# %% [markdown]
# ### **MANIPULATING ARRAYS**

# %%
##ARITHMETIC

# %%
a1
# Out:
# array([1, 2, 3])

# %%
ones=np.ones(3)
ones
# Out:
# array([1., 1., 1.])

# %%
a1+ones
# Out:
# array([2., 3., 4.])

# %%
a1-ones
# Out:
# array([0., 1., 2.])

# %%
a1*ones
# Out:
# array([1., 2., 3.])

# %%
a1/ones
# Out:
# array([1., 2., 3.])

# %%
a1%ones
# Out:
# array([0., 0., 0.])

# %%
a2
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
a1*a2
# Out:
# array([[ 1.,  4.,  9.],
#        [ 4., 10., 18.]])

# %%
a3=np.random.randint(10,size=(3,3,3))
a3
# Out:
# array([[[7, 7, 9],
#         [3, 0, 7],
#         [7, 7, 0]],
#
#        [[5, 4, 3],
#         [1, 3, 1],
#         [3, 4, 3]],
#
#        [[1, 9, 5],
#         [9, 1, 2],
#         [3, 2, 2]]])

# %%
#how can we reshape a2 to be compatible with a3
#how to reshape a numpy array
reshaped_a2 = np.reshape(a2, (1, 2, 3))
reshaped_a2*a3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-622f89aa01f7> in <cell line: 4>()
#       2 #how to reshape a numpy array
#       3 reshaped_a2 = np.reshape(a2, (1, 2, 3))
# ----> 4 reshaped_a2*a3
#
# ValueError: operands could not be broadcast together with shapes (1,2,3) (3,3,3)

# %%
np.exp(a1)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
np.log(a1)
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %% [markdown]
# ### AGGREGATION
# performing the same operations on a number of things

# %%
l1=[1,2,3]
type(l1)
# Out:
# list

# %%
sum(l1)
# Out:
# 6

# %%
a1
# Out:
# array([1, 2, 3])

# %%
np.sum(a1)
# Out:
# 6

# %%
massive_array = np.random.random(100000)
massive_array
# Out:
# array([0.63437987, 0.5229062 , 0.41488598, ..., 0.50655705, 0.46531604,
#        0.99133822])

# %%
massive_array[:100]
# Out:
# array([0.63437987, 0.5229062 , 0.41488598, 0.00142688, 0.09226235,
#        0.70939439, 0.5243456 , 0.69616046, 0.95546832, 0.68291385,
#        0.05312869, 0.30885268, 0.59259469, 0.23512041, 0.964971  ,
#        0.94504822, 0.84840088, 0.472324  , 0.84147671, 0.13111064,
#        0.30873366, 0.46299639, 0.7418472 , 0.48582523, 0.13687612,
#        0.34353653, 0.32442617, 0.3004189 , 0.1655014 , 0.41490177,
#        0.44812066, 0.77490038, 0.7963907 , 0.52239013, 0.4606303 ,
#        0.7782136 , 0.88728895, 0.67491877, 0.80047905, 0.93911135,
#        0.04065581, 0.87567172, 0.27656307, 0.4757645 , 0.79676096,
#        0.71724223, 0.14714757, 0.65874826, 0.06925207, 0.35707063,
#        0.81282955, 0.42770483, 0.59985444, 0.72816128, 0.82122761,
#        0.76051512, 0.00714328, 0.42025683, 0.46313622, 0.0554995 ,
#        0.54144213, 0.60777075, 0.82845319, 0.94180927, 0.12814785,
#        0.23043067, 0.6591584 , 0.13247399, 0.22407864, 0.57486259,
# ...

# %%
# %timeit sum(massive_array)
# %timeit np.sum(massive_array)
# Out:
# 11.8 ms ± 2.88 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 36.7 µs ± 855 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
a2
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
np.mean(a2)
# Out:
# 3.5

# %%
np.max(a2)
# Out:
# 6.0

# %%
np.min(a2)
# Out:
# 1.0

# %%
np.std(a2)   #standard deviation (std=  measure of how spread out a grp of number is from the mean)
# Out:
# 1.707825127659933

# %%
np.var(a2)  #variance (variance = measure of the average degree to which each number is different to the mean )
# higher var = wider range of numbers
#lower var = lower range of numbers
# Out:
# 2.9166666666666665

# %%
#standard deviation = sqrt of variance
np.sqrt(np.var(a2))
# Out:
# 1.707825127659933

# %%
#demo of std and var

high_var=np.array([1,100,200,300,4000,5000])
low_var=np.array([2,4,6,8,10])

# %%
np.var(high_var),np.var(low_var)
# Out:
# (4296133.472222221, 8.0)

# %%
np.std(high_var),np.std(low_var)
# Out:
# (2072.711623024829, 2.8284271247461903)

# %%
np.mean(high_var),np.mean(low_var)
# Out:
# (1600.1666666666667, 6.0)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(high_var)
# Out:
# (array([4., 0., 0., 0., 0., 0., 0., 1., 0., 1.]),
#  array([1.0000e+00, 5.0090e+02, 1.0008e+03, 1.5007e+03, 2.0006e+03,
#         2.5005e+03, 3.0004e+03, 3.5003e+03, 4.0002e+03, 4.5001e+03,
#         5.0000e+03]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(low_var)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([ 2. ,  2.8,  3.6,  4.4,  5.2,  6. ,  6.8,  7.6,  8.4,  9.2, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
#reshape and transpose!

# %%
a2.shape
# Out:
# (2, 3)

# %%
a2.reshape(2,3,1).shape
# Out:
# (2, 3, 1)

# %%
a3=np.random.randint(10,size=(2,3,3))
a3
# Out:
# array([[[6, 3, 2],
#         [6, 7, 1],
#         [8, 7, 1]],
#
#        [[5, 4, 8],
#         [6, 4, 5],
#         [3, 9, 0]]])

# %%
a2_reshaped=a2.reshape(2,3,1)
a2_reshaped
# Out:
# array([[[1.],
#         [2.],
#         [3.]],
#
#        [[4.],
#         [5.],
#         [6.]]])

# %%
a2_reshaped * a3
# Out:
# array([[[ 6.,  3.,  2.],
#         [12., 14.,  2.],
#         [24., 21.,  3.]],
#
#        [[20., 16., 32.],
#         [30., 20., 25.],
#         [18., 54.,  0.]]])

# %%
#transpose
a2
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
a2.T
# Out:
# array([[1., 4.],
#        [2., 5.],
#        [3., 6.]])

# %% [markdown]
# ### **DOT PRODUCT**

# %%
np.random.seed(0)
mat1 = np.random.randint(10,size=(5,3))
mat2 = np.random.randint(10,size=(5,3))

# %%
mat1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1]])

# %%
mat2
# Out:
# array([[6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9],
#        [4, 3, 0],
#        [3, 5, 0]])

# %%
#element wise multiplication (hadamard product)
mat1*mat2
# Out:
# array([[30,  0, 21],
#        [24,  7, 45],
#        [27, 40, 18],
#        [16, 21,  0],
#        [24, 40,  0]])

# %%
np.dot(mat1,mat2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-ca650ca9bbb3> in <cell line: 1>()
# ----> 1 np.dot(mat1,mat2)
#
# ValueError: shapes (5,3) and (5,3) not aligned: 3 (dim 1) != 5 (dim 0)

# %%
#transpose mat1
mat1.T
# Out:
# array([[5, 3, 3, 4, 8],
#        [0, 7, 5, 7, 8],
#        [3, 9, 2, 6, 1]])

# %%
mat2.shape, mat1.shape
# Out:
# ((5, 3), (5, 3))

# %%
mat1.shape, mat2.T.shape
# Out:
# ((5, 3), (3, 5))

# %%
mat3 = np.dot(mat1,mat2.T)
mat3
# Out:
# array([[ 51,  55,  72,  20,  15],
#        [130,  76, 164,  33,  44],
#        [ 67,  39,  85,  27,  34],
#        [115,  69, 146,  37,  47],
#        [111,  77, 145,  56,  64]])

# %%
mat3.shape
# Out:
# (5, 5)

# %% [markdown]
# ### **COMPARISION OPERATORS**

# %%
a1
# Out:
# array([1, 2, 3])

# %%
a2
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
a2>a2
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
a1>a2
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
bool_ar = a1>=a2
bool_ar
# Out:
# array([[ True,  True,  True],
#        [False, False, False]])

# %%
type(bool_ar) , bool_ar.dtype
# Out:
# (numpy.ndarray, dtype('bool'))

# %%
a1 > 5
# Out:
# array([False, False, False])

# %%
a1 == a1
# Out:
# array([ True,  True,  True])

# %%
a1== a2
# Out:
# array([[ True,  True,  True],
#        [False, False, False]])

# %% [markdown]
# ### **SORTING ARRAYS**

# %%
random_array
# Out:
# array([[9, 4, 1, 4, 5],
#        [6, 1, 0, 2, 4],
#        [0, 1, 1, 1, 5]])

# %%
np.sort(random_array)
# Out:
# array([[1, 4, 4, 5, 9],
#        [0, 1, 2, 4, 6],
#        [0, 1, 1, 1, 5]])

# %%
random_array
# Out:
# array([[9, 4, 1, 4, 5],
#        [6, 1, 0, 2, 4],
#        [0, 1, 1, 1, 5]])

# %%
np.argsort(random_array) #np.argsort(random_array) will return an array of indices that would sort random_array.
# Out:
# array([[2, 1, 3, 4, 0],
#        [2, 1, 3, 4, 0],
#        [0, 1, 2, 3, 4]])

# %%
np.argmin(a1)  # min value in a1 appears at which index
# Out:
# 0

# %%
np.argmax(a1)
# Out:
# 2

# %%
np.argmax(random_array, axis = 1)
# Out:
# array([0, 0, 4])

# %%
np.argmax(random_array, axis = 0)
# Out:
# array([0, 0, 0, 0, 0])

# %% [markdown]
# ### **PRACTICAL EXAMPLE **

# %%
from IPython.display import Image

Image("/content/STIM_Cute-Little-Panda-scaled.jpeg")

# %%
#turn an image into a numpy array
from matplotlib.image import imread

panda = imread("/content/STIM_Cute-Little-Panda-scaled.jpeg")
panda
# Out:
# array([[[35, 28, 22],
#         [35, 28, 22],
#         [35, 28, 22],
#         ...,
#         [64, 88, 74],
#         [64, 88, 74],
#         [64, 88, 74]],
#
#        [[34, 27, 21],
#         [34, 27, 21],
#         [34, 27, 21],
#         ...,
#         [63, 87, 73],
#         [63, 87, 73],
#         [63, 87, 73]],
#
#        [[34, 25, 20],
#         [34, 25, 20],
#         [34, 25, 20],
#         ...,
#         [63, 87, 73],
#         [63, 87, 73],
#         [63, 87, 73]],
#
#        ...,
#
#        [[37, 22, 15],
#         [37, 24, 16],
#         [39, 26, 18],
#         ...,
#         [64, 56, 45],
#         [63, 55, 44],
#         [63, 55, 44]],
#
#        [[39, 24, 17],
#         [40, 25, 18],
#         [40, 27, 19],
#         ...,
#         [62, 54, 43],
#         [63, 55, 44],
#         [63, 55, 44]],
#
#        [[41, 26, 19],
#         [41, 26, 19],
#         [41, 26, 19],
#         ...,
#         [60, 52, 41],
#         [62, 54, 43],
#         [62, 54, 43]]], dtype=uint8)

# %%
type(panda)
# Out:
# numpy.ndarray

# %%
panda.size, panda.shape, panda.ndim
# Out:
# (13102080, (2560, 1706, 3), 3)
